# %%
from diffusers import StableDiffusionPipeline
import torch

# %%
model_id = "CompVis/stable-diffusion-v1-4"
pipe = StableDiffusionPipeline.from_pretrained(model_id,torch_dtype=torch.float16)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
pipe = pipe.to(device)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\huggingface_hub\file_download.py:768: UserWarning: Not enough free disk space to download the file. The expected file size is: 3438.17 MB. The target location C:\Users\dhyey.sutariya\.cache\huggingface\hub\models--CompVis--stable-diffusion-v1-4\blobs only has 2897.35 MB free disk space.
#   warnings.warn(
# Fetching 16 files: 100%|██████████| 16/16 [02:18<00:00,  8.67s/it]
# Loading pipeline components...:  57%|█████▋    | 4/7 [00:51<00:41, 13.68s/it]You are using a model of type clip_text_model to instantiate a model of type clip. This is not supported for all configurations of models and can yield errors.
# Loading weights: 100%|██████████| 196/196 [00:07<00:00, 26.42it/s, Materializing param=text_model.final_layer_norm.weight]
# CLIPTextModel LOAD REPORT from: C:\Users\dhyey.sutariya\.cache\huggingface\hub\models--CompVis--stable-diffusion-v1-4\snapshots\133a221b8aa7292a167afc5127cb63fb5005638b\text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights: 100%|██████████| 396/396 [00:12<00:00, 32.65it/s, Materializing param=visual_projection.weight]
# StableDiffusionSafetyChecker LOAD REPORT from: C:\Users\dhyey.sutariya\.cache\huggingface\hub\models--CompVis--stable-diffusion-v1-4\snapshots\133a221b8aa7292a167afc5127cb63fb5005638b\safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading pipeline components...: 100%|██████████| 7/7 [01:14<00:00, 10.62s/it]
# Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# cpu

# %%
prompt = "Flying Cars"
with torch.autocast('cuda'):
    image = pipe(prompt).images[0]

image.save('generated_image.png')
# Out:
# C:\Users\dhyey.sutariya\AppData\Local\Temp\ipykernel_16044\484138232.py:2: UserWarning: CUDA is not available or torch_xla is imported. Disabling autocast.
#   with torch.autocast('cuda'):
#   0%|          | 0/50 [11:18<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 prompt = "Flying Cars"
#       2 with torch.autocast('cuda'):
# ----> 3     image = pipe(prompt).images[0]
#       5 image.save('generated_image.png')
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\diffusers\pipelines\stable_diffusion\pipeline_stable_diffusion.py:1041, in StableDiffusionPipeline.__call__(self, prompt, height, width, num_inference_steps, timesteps, sigmas, guidance_scale, negative_prompt, num_images_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, ip_adapter_image, ip_adapter_image_embeds, output_type, return_dict, cross_attention_kwargs, guidance_rescale, clip_skip, callback_on_step_end, callback_on_step_end_tensor_inputs, **kwargs)
#    1038     latent_model_input = self.scheduler.scale_model_input(latent_model_input, t)
#    1040 # predict the noise residual
# -> 1041 noise_pred = self.unet(
#    1042     latent_model_input,
#    1043     t,
#    1044     encoder_hidden_states=prompt_embeds,
#    1045     timestep_cond=timestep_cond,
#    1046     cross_attention_kwargs=self.cross_attention_kwargs,
#    1047     added_cond_kwargs=added_cond_kwargs,
#    1048     return_dict=False,
#    1049 )[0]
#    1051 # perform guidance
#    1052 if self.do_classifier_free_guidance:
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\diffusers\models\unets\unet_2d_condition.py:1153, in UNet2DConditionModel.forward(self, sample, timestep, encoder_hidden_states, class_labels, timestep_cond, attention_mask, cross_attention_kwargs, added_cond_kwargs, down_block_additional_residuals, mid_block_additional_residual, down_intrablock_additional_residuals, encoder_attention_mask, return_dict)
#    1150     if is_adapter and len(down_intrablock_additional_residuals) > 0:
#    1151         additional_residuals["additional_residuals"] = down_intrablock_additional_residuals.pop(0)
# -> 1153     sample, res_samples = downsample_block(
#    1154         hidden_states=sample,
#    1155         temb=emb,
#    1156         encoder_hidden_states=encoder_hidden_states,
#    1157         attention_mask=attention_mask,
#    1158         cross_attention_kwargs=cross_attention_kwargs,
#    1159         encoder_attention_mask=encoder_attention_mask,
#    1160         **additional_residuals,
#    1161     )
#    1162 else:
#    1163     sample, res_samples = downsample_block(hidden_states=sample, temb=emb)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\diffusers\models\unets\unet_2d_blocks.py:1270, in CrossAttnDownBlock2D.forward(self, hidden_states, temb, encoder_hidden_states, attention_mask, cross_attention_kwargs, encoder_attention_mask, additional_residuals)
#    1268 else:
#    1269     hidden_states = resnet(hidden_states, temb)
# -> 1270     hidden_states = attn(
#    1271         hidden_states,
#    1272         encoder_hidden_states=encoder_hidden_states,
#    1273         cross_attention_kwargs=cross_attention_kwargs,
#    1274         attention_mask=attention_mask,
#    1275         encoder_attention_mask=encoder_attention_mask,
#    1276         return_dict=False,
#    1277     )[0]
#    1279 # apply additional residuals to the output of the last pair of resnet and attention blocks
#    1280 if i == len(blocks) - 1 and additional_residuals is not None:
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\diffusers\models\transformers\transformer_2d.py:427, in Transformer2DModel.forward(self, hidden_states, encoder_hidden_states, timestep, added_cond_kwargs, class_labels, cross_attention_kwargs, attention_mask, encoder_attention_mask, return_dict)
#     416         hidden_states = self._gradient_checkpointing_func(
#     417             block,
#     418             hidden_states,
#    (...)    424             class_labels,
#     425         )
#     426     else:
# --> 427         hidden_states = block(
#     428             hidden_states,
#     429             attention_mask=attention_mask,
#     430             encoder_hidden_states=encoder_hidden_states,
#     431             encoder_attention_mask=encoder_attention_mask,
#     432             timestep=timestep,
#     433             cross_attention_kwargs=cross_attention_kwargs,
#     434             class_labels=class_labels,
#     435         )
#     437 # 3. Output
#     438 if self.is_input_continuous:
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\diffusers\models\attention.py:1069, in BasicTransformerBlock.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, timestep, cross_attention_kwargs, class_labels, added_cond_kwargs)
#    1067     ff_output = _chunked_feed_forward(self.ff, norm_hidden_states, self._chunk_dim, self._chunk_size)
#    1068 else:
# -> 1069     ff_output = self.ff(norm_hidden_states)
#    1071 if self.norm_type == "ada_norm_zero":
#    1072     ff_output = gate_mlp.unsqueeze(1) * ff_output
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\diffusers\models\attention.py:1741, in FeedForward.forward(self, hidden_states, *args, **kwargs)
#    1739     deprecate("scale", "1.0.0", deprecation_message)
#    1740 for module in self.net:
# -> 1741     hidden_states = module(hidden_states)
#    1742 return hidden_states
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\diffusers\models\activations.py:117, in GEGLU.forward(self, hidden_states, *args, **kwargs)
#     115     deprecation_message = "The `scale` argument is deprecated and will be ignored. Please remove it, as passing it will raise an error in the future. `scale` should directly be passed while calling the underlying pipeline component i.e., via `cross_attention_kwargs`."
#     116     deprecate("scale", "1.0.0", deprecation_message)
# --> 117 hidden_states = self.proj(hidden_states)
#     118 if is_torch_npu_available():
#     119     # using torch_npu.npu_geglu can run faster and save memory on NPU.
#     120     return torch_npu.npu_geglu(hidden_states, dim=-1, approximate=1)[0]
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
