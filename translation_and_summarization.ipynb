# %% [markdown]
# ## Translation

# %%
from transformers import pipeline 
import torch

# %%
translator = pipeline(task="translation_XX_to_YY",
                      model="facebook/nllb-200-distilled-600M",
                      torch_dtype=torch.bfloat16)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 translator = pipeline(task="translation_XX_to_YY",
#       2                       model="facebook/nllb-200-distilled-600M",
#       3                       torch_dtype=torch.bfloat16)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\transformers\pipelines\__init__.py:777, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     770         pipeline_class = get_class_from_dynamic_module(
#     771             class_ref,
#     772             model,
#     773             code_revision=code_revision,
#     774             **hub_kwargs,
#     775         )
#     776 else:
# ...

# %%
text = """\
My puppy is adorable, \
Your kitten is cute.
Her panda is friendly.
His llama is thoughtful. \
We all have nice pets!"""

# %%
text_translated = translator(text,
                             src_lang="eng_Latn",
                             tgt_lang="hin_Deva")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 text_translated = translator(text,
#       2                              src_lang="eng_Latn",
#       3                              tgt_lang="hin_Deva")
#
# NameError: name 'translator' is not defined

# %% [markdown]
# ## Summarization

# %%
summarizer = pipeline(task="text-generation",
                      model="facebook/bart-large-cnn",
                      torch_dtype=torch.bfloat16)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Please make sure the generation config includes `forced_bos_token_id=0`.
# Loading weights: 100%|██████████| 316/316 [00:01<00:00, 299.31it/s, Materializing param=model.decoder.layers.11.self_attn_layer_norm.weight]
# BartForCausalLM LOAD REPORT from: facebook/bart-large-cnn
# Key                                                       | Status     |  |
# ----------------------------------------------------------+------------+--+-
# model.encoder.layers.{0...11}.self_attn.q_proj.weight     | UNEXPECTED |  |
# model.encoder.layers.{0...11}.final_layer_norm.bias       | UNEXPECTED |  |
# model.encoder.layers.{0...11}.fc2.bias                    | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.q_proj.bias       | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn_layer_norm.weight | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.k_proj.bias       | UNEXPECTED |  |
# ...

# %%
text = """Dear Team,

Greetings!

Pause for a moment and think about your day.

From unlocking your phone with facial recognition to receiving curated recommendations, navigating traffic, or automating routine tasks - AI is already part of your everyday life. It’s not a distant concept. It’s here, quietly influencing how we live and work.

We are excited to invite you to a special Leadership Talk on How AI Shapes Our Daily Life, led by Madhav Anadkat. 

In this session, we will explore:

How AI is influencing our daily decisions - often without us realizing it
What AI means for the future of our roles and industry
How we can responsibly and strategically embrace AI
How leadership plays a role in navigating this transformation
This won’t be a technical lecture. It will be a thought-provoking conversation - one that connects technology with people, purpose, and possibility.

Session Details :

Date : 20th February ,2026

Time : 10:30 a.m. to 11:30 a.m.

Venue : 9th Floor Training Room

 

As we continue to evolve as an organization, understanding AI is not optional - it’s essential. And there’s no better person to guide this discussion than someone who has been instrumental in shaping who we are today.

We strongly encourage you to join, engage, and be part of this important dialogue.

Let’s learn together !

Looking forward to seeing you there.

 

 

Regards,

Team HR"""

# %%
summary = summarizer(text,
                     min_length=10,
                     max_length=1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 summary = summarizer(text,
#       2                      min_length=10,
#       3                      max_length=1000)
#
# File c:\Users\dhyey.sutariya\Python_AI Learning\HuggingFaceTransformers\.venv\Lib\site-packages\transformers\pipelines\text_generation.py:293, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     243 def __call__(self, text_inputs, **kwargs):
#     244     """
#     245     Complete the prompt(s) given as inputs.
#     246
#    (...)    291           ids of the generated text.
#     292     """
# --> 293     return super().__call__(text_inputs, **kwargs)
#
# ...

# %%
summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 summary
#
# NameError: name 'summary' is not defined
